# %%
import numpy as np
import pandas as pd

# %%
beer = pd.read_csv("beer.csv")

# %%
print(beer)
# Out:
#            Data Temperatura Media (C) Temperatura Minima (C)  \
# 0    2015-01-01                  27,3                   23,9
# 1    2015-01-02                 27,02                   24,5
# 2    2015-01-03                 24,82                   22,4
# 3    2015-01-04                 23,98                   21,5
# 4    2015-01-05                 23,82                     21
# ..          ...                   ...                    ...
# 936         NaN                   NaN                    NaN
# 937         NaN                   NaN                    NaN
# 938         NaN                   NaN                    NaN
# 939         NaN                   NaN                    NaN
# 940         NaN                   NaN                    NaN
#
#     Temperatura Maxima (C) Precipitacao (mm)  Final de Semana  \
# 0                     32,5                 0              0.0
# 1                     33,5                 0              0.0
# 2                     29,9                 0              1.0
# 3                     28,6               1,2              1.0
# 4                     28,3                 0              0.0
# ..                     ...               ...              ...
# 936                    NaN               NaN              NaN
# 937                    NaN               NaN              NaN
# 938                    NaN               NaN              NaN
# 939                    NaN               NaN              NaN
# 940                    NaN               NaN              NaN
#
#      Consumo de cerveja (litros)
# 0                         25.461
# 1                         28.972
# 2                         30.814
# 3                         29.799
# 4                         28.900
# ..                           ...
# 936                          NaN
# 937                          NaN
# 938                          NaN
# 939                          NaN
# 940                          NaN
#
# [941 rows x 7 columns]

# %%
beer.shape
# Out:
# (941, 7)

# %%
beer.size
# Out:
# 6587

# %%
beer.describe()
# Out:
#        Final de Semana  Consumo de cerveja (litros)
# count       365.000000                   365.000000
# mean          0.284932                    25.401367
# std           0.452001                     4.399143
# min           0.000000                    14.343000
# 25%           0.000000                    22.008000
# 50%           0.000000                    24.867000
# 75%           1.000000                    28.631000
# max           1.000000                    37.937000

# %%
beer.columns
# Out:
# Index(['Data', 'Temperatura Media (C)', 'Temperatura Minima (C)',
#        'Temperatura Maxima (C)', 'Precipitacao (mm)', 'Final de Semana',
#        'Consumo de cerveja (litros)'],
#       dtype='object')

# %%
beer.isnull()
# Out:
#       Data  Temperatura Media (C)  Temperatura Minima (C)  \
# 0    False                  False                   False
# 1    False                  False                   False
# 2    False                  False                   False
# 3    False                  False                   False
# 4    False                  False                   False
# ..     ...                    ...                     ...
# 936   True                   True                    True
# 937   True                   True                    True
# 938   True                   True                    True
# 939   True                   True                    True
# 940   True                   True                    True
#
#      Temperatura Maxima (C)  Precipitacao (mm)  Final de Semana  \
# 0                     False              False            False
# 1                     False              False            False
# 2                     False              False            False
# 3                     False              False            False
# 4                     False              False            False
# ..                      ...                ...              ...
# 936                    True               True             True
# 937                    True               True             True
# 938                    True               True             True
# 939                    True               True             True
# 940                    True               True             True
#
#      Consumo de cerveja (litros)
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                          False
# ..                           ...
# 936                         True
# 937                         True
# 938                         True
# 939                         True
# 940                         True
#
# [941 rows x 7 columns]

# %%
beer.isnull().sum()
# Out:
# Data                           576
# Temperatura Media (C)          576
# Temperatura Minima (C)         576
# Temperatura Maxima (C)         576
# Precipitacao (mm)              576
# Final de Semana                576
# Consumo de cerveja (litros)    576
# dtype: int64

# %%
beer.isna()
# Out:
#       Data  Temperatura Media (C)  Temperatura Minima (C)  \
# 0    False                  False                   False
# 1    False                  False                   False
# 2    False                  False                   False
# 3    False                  False                   False
# 4    False                  False                   False
# ..     ...                    ...                     ...
# 936   True                   True                    True
# 937   True                   True                    True
# 938   True                   True                    True
# 939   True                   True                    True
# 940   True                   True                    True
#
#      Temperatura Maxima (C)  Precipitacao (mm)  Final de Semana  \
# 0                     False              False            False
# 1                     False              False            False
# 2                     False              False            False
# 3                     False              False            False
# 4                     False              False            False
# ..                      ...                ...              ...
# 936                    True               True             True
# 937                    True               True             True
# 938                    True               True             True
# 939                    True               True             True
# 940                    True               True             True
#
#      Consumo de cerveja (litros)
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                          False
# ..                           ...
# 936                         True
# 937                         True
# 938                         True
# 939                         True
# 940                         True
#
# [941 rows x 7 columns]

# %%
beer.isna().any()
# Out:
# Data                           True
# Temperatura Media (C)          True
# Temperatura Minima (C)         True
# Temperatura Maxima (C)         True
# Precipitacao (mm)              True
# Final de Semana                True
# Consumo de cerveja (litros)    True
# dtype: bool

# %%
beer.dropna(how='all', inplace=True)

# %%
beer.replace({',':'.'},regex = True, inplace=True)

# %%
beer['Data'] = pd.to_datetime(beer['Data'])

# %%
beer = beer.astype({'Temperatura Media (C)':'float','Temperatura Minima (C)':'float','Temperatura Maxima (C)':'float','Consumo de cerveja (litros)':'float'})

# %%
beer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 365 entries, 0 to 364
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Data                         365 non-null    datetime64[ns]
#  1   Temperatura Media (C)        365 non-null    float64
#  2   Temperatura Minima (C)       365 non-null    float64
#  3   Temperatura Maxima (C)       365 non-null    float64
#  4   Precipitacao (mm)            365 non-null    object
#  5   Final de Semana              365 non-null    float64
#  6   Consumo de cerveja (litros)  365 non-null    float64
# dtypes: datetime64[ns](1), float64(5), object(1)
# memory usage: 22.8+ KB

# %%
days = ['Monday', 'Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']
beer.drop(['Data'], axis=1)
# Out:
#      Temperatura Media (C)  Temperatura Minima (C)  Temperatura Maxima (C)  \
# 0                    27.30                    23.9                    32.5
# 1                    27.02                    24.5                    33.5
# 2                    24.82                    22.4                    29.9
# 3                    23.98                    21.5                    28.6
# 4                    23.82                    21.0                    28.3
# ..                     ...                     ...                     ...
# 360                  24.00                    21.1                    28.2
# 361                  22.64                    21.1                    26.7
# 362                  21.68                    20.3                    24.1
# 363                  21.38                    19.3                    22.4
# 364                  24.76                    20.2                    29.0
#
#     Precipitacao (mm)  Final de Semana  Consumo de cerveja (litros)
# 0                   0              0.0                       25.461
# 1                   0              0.0                       28.972
# 2                   0              1.0                       30.814
# 3                 1.2              1.0                       29.799
# 4                   0              0.0                       28.900
# ..                ...              ...                          ...
# 360              13.6              1.0                       32.307
# 361                 0              0.0                       26.095
# 362              10.3              0.0                       22.309
# 363               6.3              0.0                       20.467
# 364                 0              0.0                       22.446
#
# [365 rows x 6 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(11,6))
ax = sns.boxplot(data=beer, x='Data',y='Consumo de cerveja (litros)', color="indianred")

# %%
plt.figure(figsize=(12,5))
sns.histplot(beer , x="Consumo de cerveja (litros)" , color='olive')
# Out:
# <Axes: xlabel='Consumo de cerveja (litros)', ylabel='Count'>

# %%
plt.figure(figsize=(23,5))
sns.histplot(beer , x="Precipitacao (mm)" , color='violet')
# Out:
# <Axes: xlabel='Precipitacao (mm)', ylabel='Count'>

# %%
plt.figure(figsize=(12,5))
sns.histplot(beer , x="Final de Semana" , color='teal')
# Out:
# <Axes: xlabel='Final de Semana', ylabel='Count'>

# %%
plt.figure(figsize=(29,5))
sns.lineplot(x='Precipitacao (mm)', y='Data', data=beer, color='limegreen')
# Out:
# <Axes: xlabel='Precipitacao (mm)', ylabel='Data'>

# %%
plt.figure(figsize=(19,5))
sns.lineplot(x='Precipitacao (mm)', y='Final de Semana', data=beer, color='saddlebrown')
# Out:
# <Axes: xlabel='Precipitacao (mm)', ylabel='Final de Semana'>

# %%
plt.figure(figsize=(10,5))
sns.lmplot(x= 'Consumo de cerveja (litros)', y='Final de Semana', data=beer)

# %%
from sklearn.model_selection import train_test_split

# %%
x = beer.drop("Data", axis=1)

y= beer['Consumo de cerveja (litros)']

xtrain, xtest, ytrain, ytest = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import confusion_matrix
from sklearn import metrics

# %%
L=LinearRegression()
beer['Data'] = pd.to_numeric(pd.to_datetime(beer['Data']))
L.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
y_pred = L.predict(xtest)
print(L.score(xtest , ytest))
# Out:
# 1.0

# %%
from sklearn.model_selection import train_test_split

# %%
x = beer.drop("Consumo de cerveja (litros)", axis=1)
y= beer['Consumo de cerveja (litros)']
xtrain, xtest, ytrain, ytest = train_test_split(x,y, test_size=0.2, random_state=32)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import confusion_matrix
from sklearn import metrics

# %%
L=LinearRegression()
beer['Data'] = pd.to_numeric(pd.to_datetime(beer['Data']))
L.fit(xtrain,ytrain)
y_pred = L.predict(xtest)
print(L.score(xtest , ytest))
# Out:
# 0.4468202780485526

# %%
y_pred
# Out:
# array([23.03155808, 26.62121264, 27.39802306, 31.33220991, 26.36962724,
#        27.73838425, 25.46750538, 25.59469973, 25.30120756, 27.8600096 ,
#        21.41629419, 30.28138745, 28.60354801, 21.96888415, 23.74411225,
#        29.67332013, 25.19648907, 24.40049121, 29.19241057, 19.79439669,
#        29.90420143, 25.53420733, 27.7109567 , 28.61024136, 26.09783659,
#        26.88706724, 28.60035017, 24.99576792, 26.58804229, 26.3323053 ,
#        24.86806272, 22.07075549, 27.08748977, 29.33244187, 22.66111721,
#        27.55282502, 26.64180716, 31.12640935, 21.74109182, 22.38520096,
#        27.74388487, 25.44589144, 26.5355774 , 24.41190135, 25.37067878,
#        22.60800581, 26.39293014, 26.70074936, 27.45159396, 26.31121832,
#        23.89878144, 24.18882973, 24.31514066, 24.72133813, 21.78923367,
#        29.17255987, 26.15983696, 20.22166904, 25.98491268, 27.7305291 ,
#        27.91760905, 27.7331992 , 30.47261942, 29.87018343, 26.55720061,
#        20.17128345, 25.51356178, 22.76719232, 26.72040898, 31.22059759,
#        26.11995202, 20.92446792, 25.99855004])

# %%
ytest
# Out:
# 137    21.073
# 103    22.001
# 33     31.655
# 266    30.345
# 285    26.523
#         ...
# 146    24.258
# 18     29.265
# 23     28.348
# 151    16.228
# 226    29.621
# Name: Consumo de cerveja (litros), Length: 73, dtype: float64

# %%
sns.lmplot(x ="Data", y ="Consumo de cerveja (litros)", data = beer, order = 2)
plt.show()

# %%
regr = LinearRegression()
regr.fit(xtrain, ytrain)
print(regr.score(xtest, ytest))
y_pred = regr.predict(xtest)
# Out:
# 0.4468202780485526

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
mae = mean_absolute_error(y_true=ytest, y_pred=y_pred)

# %%
mse = mean_squared_error(y_true= ytest,y_pred=y_pred) #default=True
rmse = mean_squared_error(y_true= ytest,y_pred=y_pred,squared=False)

print("MAE:",mae)
print("MSE:",mse)
print("RMSE:",rmse)
# Out:
# MAE: 2.6356753135117406
# MSE: 10.372389858915987
# RMSE: 3.2206194837198616
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
from sklearn.metrics import confusion_matrix #confusion matrix only displays␣info of numeric data
correlation_metrics = beer.corr()
fig = plt.figure(figsize = (8,8))
sns.heatmap(correlation_metrics , vmax = 0.9 , square = True, annot=True)
plt.show()
